# %%
# Celda: cargar Excel, mostrar columnas, primeras 5 filas y describe()
import os
import pandas as pd

ruta = r"D:\Power BI + AI\Informe_Ventas.xlsx"  # ajusta si hace falta

# comprobación simple
if not os.path.exists(ruta):
    raise FileNotFoundError(f"No se encontró el archivo: {ruta}")

# carga (requiere engine openpyxl para .xlsx)
df = pd.read_excel(ruta)

# mostrar columnas
print("Columnas:", list(df.columns))

# mostrar primeras 5 filas
print("\nPrimeras 5 filas:")
display(df.head(5))  # en notebook muestra una tabla bonita

# describe (estadísticas)
print("\nDescribe (incluye no numéricas):")
display(df.describe(include='all'))
# Out:
# Columnas: ['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate', 'UnitPrice', 'CustomerID', 'Country', 'Country2']
#
# Primeras 5 filas:
# Columnas: ['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate', 'UnitPrice', 'CustomerID', 'Country', 'Country2']
#
# Primeras 5 filas:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country        Country2
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom  United Kingdom
# ...

# %%
# Calcular monto por fila y resumen por país
import pandas as pd
ruta = r'D:\Power BI + AI\Informe_Ventas.xlsx'
df = pd.read_excel(ruta)
df['Amount'] = df['Quantity'] * df['UnitPrice']
total_bruto = df['Amount'].sum()
clean_df = df[(df['Quantity'] > 0) & (df['UnitPrice'] > 0)]
total_limpio = clean_df['Amount'].sum()
amount_by_country = df.groupby('Country')['Amount'].sum().sort_values(ascending=False)
top5 = amount_by_country.head(5)
print(f'Total bruto (incluye devoluciones/valores negativos): {total_bruto:,.2f}')
print(f'Total limpio (Quantity>0 y UnitPrice>0): {total_limpio:,.2f}')
print('




print(top5.apply(lambda x: f'{x:,.2f}').to_string())print('
Top 5 países por monto:'))print(fPaís con mayor monto:')
# Out:
#   Cell In[3], line 13
#     print('
#           ^
# SyntaxError: unterminated string literal (detected at line 13)
